# %% [markdown]
# ![](https://www.dii.uchile.cl/wp-content/uploads/2021/06/Magi%CC%81ster-en-Ciencia-de-Datos.png)

# %% [markdown]
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### 👨‍🏫👩‍🏫 Cuerpo Docente:
#
# - Profesor: Sebastián Tinoco, Stefano Schiappacasse
# - Auxiliar: Melanie Peña Torres, Valentina Rojas Osorio
# - Ayudante: Valentina Zuñiga, Ángelo Muñoz
#
# ### 👨‍💻👩‍💻 Estudiantes:
# - Estudiante n°1: Sebastián Acuña U.
# - Estudiante n°2: Martín Guzmán S.
#
# _Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir._
#
# ---

# %% [markdown]
# ---
#
# ## 📖 Enunciado

# %% [markdown]
# <div align="center">
#     <img src='https://github.com/MDS7202/MDS7202/blob/main/recursos/2025-01/proyecto/proyecto.png?raw=true' style="border-radius: 12px">
# </div>

# %% [markdown]
# En el competitivo universo de las bebidas gaseosas, la empresa **SodAI Drinks 🥤** ha logrado destacarse por su creatividad, diversidad de productos y enfoque centrado en el cliente. Ofrece una extensa gama de bebidas carbonatadas que abarca distintos segmentos del mercado: desde productos premium en presentaciones sofisticadas, hasta gaseosas accesibles para el consumo masivo, disponibles en diversos tamaños y tipos de envases.
#
# La compañía opera en múltiples regiones y zonas, sirviendo a una variedad de puntos de venta que incluyen desde tiendas de conveniencia y minimarkets hasta el canal frío tradicional. Cada tipo de cliente tiene sus particularidades: algunos reciben entregas hasta 4 veces por semana, mientras que otros son visitados por la fuerza de ventas solo una vez semanalmente. Esta diversidad de perfiles representa tanto una oportunidad como un desafío comercial: ¿cómo saber qué productos tienen más chances de ser comprados por cada cliente en un momento dado?
#
# Con el objetivo de aumentar la facturación de forma inteligente y mejorar la eficiencia de su estrategia de ventas, **SodAI Drinks** decide crear una nueva célula interna de innovación: el equipo **Deep Drinkers 🤖**, cuyo propósito es aplicar ciencia de datos para anticiparse a las necesidades del cliente y potenciar el negocio desde una perspectiva basada en información.
#
# El corazón de esta iniciativa es el desarrollo de un sistema predictivo personalizado para cada cliente. Para ello, **Deep Drinkers** convoca a un equipo de Data Scientists y especialistas en *machine learning* con una misión clara: construir un modelo predictivo que, cada semana, pueda estimar la probabilidad de compra de cada producto del portafolio para cada cliente activo.
#
# El modelo deberá tener en cuenta múltiples factores, incluyendo:
# - **Tipo de cliente**, ej. "TIENDA DE CONVENIENCIA", "MINIMARKET".
# - **Frecuencia de entregas y visitas**, indicadores del nivel de actividad comercial.
# - **Ubicación geográfica** (por región y zona).
# - **Preferencias históricas de consumo**, inferidas por patrones de compra anteriores.
# - **Características del producto**, como marca, categoría, segmento, tipo de envase y tamaño
#
# El objetivo final es que, **cada semana**, se genere una tabla de productos priorizados: para cada cliente, un listado de productos ordenado por su probabilidad estimada de compra. Esta información será enviada al equipo comercial, que podrá usarla en call center, para incrementar las chances de concretar ventas al ofrecer justo lo que el cliente probablemente quiere comprar.
#
# Este proyecto representa un cambio de paradigma en la forma en que **SodAI Drinks** gestiona su fuerza de ventas: de un enfoque reactivo y generalista, a uno proactivo, basado en datos y profundamente personalizado. Así, la empresa no solo espera aumentar su rentabilidad, sino también construir relaciones más sólidas con sus clientes, ofreciéndoles recomendaciones más relevantes y oportunas.
#
# Para lograr lo anterior, el equipo **Deep Drinkers** contará con los siguientes conjuntos de datos, junto a sus respectivos atributos:
#
# - **Datos transaccionales** (`transacciones.parquet`): contiene el historial de compras realizadas por los clientes.
# 	- `customer_id`: identificador único del cliente que realizó la compra.
# 	- `product_id`: identificador único del producto comprado.
# 	- `purchase_date`: fecha en que se realizó la transacción.
# 	- `order_id`: identificar de la orden de su pedido.
# 	- `payment`	monto total pagado por la transacción.
#
# - **Datos de clientes** (`clientes.parquet`): incluye las características de cada cliente.
# 	- `customer_id`: identificador único del cliente.
# 	- `region_id`: identificador de la región geográfica donde se encuentra el cliente.
# 	- `customer_type`: tipo de cliente según el canal comercial, por ejemplo, “TIENDA DE CONVENIENCIA”.
# 	- `Y`: coordenada geográfica de latitud.
# 	- `X`: coordenada geográfica de longitud.
# 	- `num_deliver_per_week`: cantidad de entregas semanales que recibe el cliente.
# 	- `num_visit_per_week`: frecuencia de visitas de la fuerza de ventas por semana.
#
# - **Datos de productos** (`productos.parquet`): describe las características de los productos del portafolio.
# 	- `product_id`: identificador único del producto.
# 	- `brand`: marca comercial del producto.
# 	- `category`: categoría general del producto, como “BEBIDAS CARBONATADAS”.
# 	- `sub_category`: subcategoría dentro de la categoría principal, por ejemplo, “GASEOSAS”.
# 	- `segment`: segmento de mercado al que pertenece el producto, como “PREMIUM”.
# 	- `package`: tipo de envase del producto.
# 	- `size`: tamaño del producto en litros.

# %% [markdown]
# ## 📚 Reglas

# %% [markdown]
# <center>
# <img src="https://media1.tenor.com/m/0Qtv_cQ4ITsAAAAd/necohaus-grey-name.gif" width="450">

# %% [markdown]
# El proyecto consta de **dos entregas parciales** y una **entrega final** en donde la primera entrega la idea es poder reflejar lo aprendido durante la primera mitad del curso, que será sobre los contenidos relacionados a *machine learning*, la segunda será sobre los contenidos de la segunda mitad del curso relacionados a *MLOps* y por último la entrega final constará de dos partes, donde la primera será relacionada con experimentación sobre nuevos datasets que serán disponibilizados durante las últimas semanas del curso de manera incremental y una segunda parte que será el informe final escrito que deberá explicar el desarrollo del proyecto completo, como tambien los resultados y análisis de los experimentos realizados sobre los datasets incrementales. La idea es que todo el código esté desarrollado durante las primeras dos entregas y luego en la entrega final sólo se ejecute el código sobre nuevos conjuntos de datos.
#
# La idea de generar el proyecto por etapas es poder aliviar la carga de trabajo en las últimas semanas del semestre donde sabemos que están muy cargado con entregas, pruebas y exámenes de otros ramos, y así garantizamos que habiendo la desarrollado las dos primeras entregas parciales, tendrán el grueso del proyecto listo para luego experimentar y documentar.
#
# ---
# ### **Fechas de entrega**
# - **Entrega parcial 1**: 14 de Mayo
# - **Entrega parcial 2**: Por definir
# - **Entrega final**: Por definir
#
# ---
#
# ### **Requisitos del proyecto**
# - **Grupos**: Formar equipos de **2 personas**. No se aceptarán trabajos individuales o grupos con más integrantes.
# - **Consultas**: Cualquier duda fuera del horario de clases debe ser planteada en el foro correspondiente. Los mensajes enviados al equipo docente serán respondidos únicamente por este medio. Por favor, revisen las respuestas anteriores en el foro antes de realizar nuevas consultas.
# - **Plagio**: La copia o reutilización no autorizada de trabajos de otros grupos está **estrictamente prohibida**. El incumplimiento de esta norma implicará la anulación inmediata del proyecto y una posible sanción académica.
# - **Material permitido**: Pueden usar cualquier material del curso, ya sea notas, lecturas, códigos, o referencias proporcionadas por los docentes, que consideren útil para el desarrollo del proyecto.
#
# ---
#
# ### **Entregables y etapas**
#
# #### **1. Entrega Parcial 1**
# - Dispondrán de los archivos de datos **productos.parquet**, **clientes.parquet** y **transacciones.parquet** para el modelamiento inicial.
# - Utilizarán estos archivos para desarrollar lo solicitado para la entrega 1.
# - En esta etapa, se espera que apliquen todos los conocimientos aprendidos durante la primera parte del curso relacionados con *machine learning*.
# - **Informe**: No se exige un avance del informe en esta etapa, sólo un notebook con su desarrollo actual, pero se **recomienda comenzar** a redactar el informe final en paralelo para disminuir la carga académica en las etapas posteriores.
#
# #### **2. Entrega Parcial 2**
# - En esta entrega, deberán aplicar los conocimientos aprendidos durante la segunda mitad del curso sobre *MLOps*
# - Se espera que implementen estos conocimientos para desplegar su modelo elegido en la primera entrega y crear *pipelines* automatizados que simulen un entorno productivo.
# - **Informe**: similar a la primera etapa, no se exige un avance del informe, pero se **recomienda avanzar con su redacción** para evitar una acumulación de trabajo en la etapa final.
#
# #### **3. Entrega Final**
# - En la entrega final, deberán realizar dos etapas:
# 	- La primera etapa es sobre experimentación utilizando datasets incrementales que se irán disponibilizando de manera parcial, para que vayan generando predicciones con su modelo ya desplegado. El objetivo de esta etapa es poder testear su solución *end-to-end* y que vayan analizando los resultados obtenidos a medida que se van agregando más datos.
# 	- La segunda etapa consiste en redactar un informe final que deberá explicar el desarrollo completo de tu proyecto y un análisis profundo de sus resultados de experimentación. Este informe debera incluir a lo menos las siguientes secciones:
# 		- Análisis exploratorio de datos
# 		- Metodología aplicada
# 		- Selección y entrenamiento de modelos
# 		- Evaluación de resultados
# 		- Optimización de modelos
# 		- Interpretabilidad
# 		- Re-entrenamiento
# 		- Tracking con MLFlow
# 		- Creación de la aplicación web con Gradio y FastAPI
#
# Es **altamente recomendable** ir redactando el informe en paralelo al desarrollo de los modelos para garantizar que toda la información relevante quede documentada adecuadamente.
#
# ### Nota Final
#
# La calificación final de su proyecto se calculará utilizando la siguiente ponderación:
#
# $$Nota Final = 0.30 * EntregaParcial1 + 0.40 * EntregaParcial2 + 0.30 * EntregaFinal$$
#
# ---
#
# ### **Instrucciones importantes**
#
# 1. **Formato del informe**:
#    - El informe debe estar integrado dentro de un **Jupyter Notebook**. No es necesario subirlo a una plataforma externa, pero debe cumplir con los siguientes requisitos:
#      - Estructura clara y ordenada.
#      - Código acompañado de explicaciones detalladas.
#      - Resultados presentados de forma visual y analítica.
#
# 2. **Descuento por informes deficientes**:
#    - Cualquier sección del informe que no tenga una explicación adecuada o no respete el formato será penalizada con un descuento en la nota. Esto incluye código sin comentarios o análisis que no sean coherentes con los resultados presentados.
#    - Comentarios sin formatear de ChatGPT o herramientas similares serán penalizados (e.g: "Inserta tu modelo acá", etc.)

# %% [markdown]
# # 📬 Entrega Parcial 1 (30% del Proyecto)

# %% [markdown]
# ### 📪 Fecha de Entrega: 14 de Mayo

# %% [markdown]
# ## 📌 Abstract [0.25 puntos]
#
# <center>
# <img src="https://i.redd.it/h5ptnsyabqvd1.gif" width="400" height="300">

# %% [markdown]
# En esta sección, deben redactar un Abstract claro y conciso para su proyecto. El Abstract debe responder a las siguientes preguntas clave:
#
# - **Descripción del problema**: ¿Cuál es el objetivo del proyecto? ¿Qué se intenta predecir o analizar?
# - **Datos de entrada**: ¿Qué datos tienen disponibles? ¿Cuáles son sus principales características?
# - **Métrica de evaluación**: ¿Cómo medirán el desempeño de sus modelos? Expliquen por qué eligieron esta métrica basándose en el análisis exploratorio de los datos.
# - **Modelos y transformaciones**: ¿Qué modelos utilizarán y por qué? ¿Qué transformaciones o preprocesamientos aplicaron a los datos?
# - **Resultados generales**: ¿El modelo final cumplió con los objetivos del proyecto? ¿Cuáles fueron las conclusiones más importantes?
#
# **Importante**: Escriban esto después de haber resuelto el resto de la tarea.

# %% [markdown]
# El objetivo del proyecto es crear una

# %% [markdown]
# ## 📌 Pre-procesamiento [0.5 puntos]
#
# <center>
# <img src="https://media0.giphy.com/media/10zsjaH4g0GgmY/giphy.gif?cid=6c09b9523xtlunksc9amikw09zk1bmiqwjqnt70ae82rk877&ep=v1_gifs_search&rid=giphy.gif&ct=g" width="400" height="300">

# %% [markdown]
# Tal como en muchos otros problemas de negocio, los datos probablemente deben ser pre procesados antes de aplicar cualquier técnica de analítica. Bajo esa premisa, en esta sección deben desarrollar código que les permita **preparar los datos** de tal forma que les permita resolver el problema planteado. Para esto, pueden aplicar procesamientos como:
#
# - Transformaciones de tipo de dato (str, int, etc)
# - Cruce de información
# - Eliminación de duplicados
# - Filtros de fila y/o columnas
#
# *Hint: ¿Qué forma debería tener la data para resolver un problema de aprendizaje supervisado?*
#
# Todo proceso llevado a cabo debe estar bien documentado y justificado en el informe, explicando el por qué se decidió realizar en función de los datos presentados y los objetivos planteados del proyecto.

# %% [markdown]
# - **Datos transaccionales** (`transacciones.parquet`): contiene el historial de compras realizadas por los clientes.
# 	- `customer_id`: identificador único del cliente que realizó la compra.
# 	- `product_id`: identificador único del producto comprado.
# 	- `purchase_date`: fecha en que se realizó la transacción.
# 	- `order_id`: identificar de la orden de su pedido.
# 	- `items`	cantidad de bultos comprados por el cliente en esa transacción..
#
# - **Datos de clientes** (`clientes.parquet`): incluye las características de cada cliente.
# 	- `customer_id`: identificador único del cliente.
# 	- `region_id`: identificador de la región geográfica donde se encuentra el cliente.
# 	- `customer_type`: tipo de cliente según el canal comercial, por ejemplo, “TIENDA DE CONVENIENCIA”.
# 	- `Y`: coordenada geográfica de latitud.
# 	- `X`: coordenada geográfica de longitud.
# 	- `num_deliver_per_week`: cantidad de entregas semanales que recibe el cliente.
# 	- `num_visit_per_week`: frecuencia de visitas de la fuerza de ventas por semana.
#
# - **Datos de productos** (`productos.parquet`): describe las características de los productos del portafolio.
# 	- `product_id`: identificador único del producto.
# 	- `brand`: marca comercial del producto.
# 	- `category`: categoría general del producto, como “BEBIDAS CARBONATADAS”.
# 	- `sub_category`: subcategoría dentro de la categoría principal, por ejemplo, “GASEOSAS”.
# 	- `segment`: segmento de mercado al que pertenece el producto, como “PREMIUM”.
# 	- `package`: tipo de envase del producto.
# 	- `size`: tamaño del producto en litros.

# %%
# LIBRERÍAS A UTILIZAR
import pandas as pd
import matplotlib.pyplot as plt
import gc

import warnings
warnings.filterwarnings("ignore")

# %%
#se abren los datasets originales
data_clientes = pd.read_parquet('clientes.parquet')
data_productos = pd.read_parquet('productos.parquet')
data_transacciones = pd.read_parquet('transacciones.parquet')

#Mencionar que solo se transaccionan 114 productos de 971 y solo 1490 clietes transaccionan,  de los 1569 totales

# %% [markdown]
# ### Visualización de datasets e información de columnas

# %% [markdown]
# #### Data clientes

# %%
data_clientes
# Out:
#        customer_id  region_id  zone_id customer_type          Y           X  \
# 10705       256017         80     5148     ABARROTES -46.474800 -108.045140
# 10706       255780         80     5148     ABARROTES -46.520282 -107.961052
# 10707       254655         80     5148     ABARROTES -46.537640 -107.909280
# 10708       254445         80     5148     ABARROTES -46.543526 -107.917954
# 10709       254403         80     5148     ABARROTES -46.540856 -107.905792
# ...            ...        ...      ...           ...        ...         ...
# 12269        64218         80     5148     ABARROTES -46.521026 -107.884928
# 12270        61353         80     5148     ABARROTES -46.558718 -107.860564
# 12271        59700         80     5148     ABARROTES -46.557180 -107.863080
# 12272        56871         80     5148     ABARROTES -46.559136 -107.924664
# 12273        56868         80     5148     MAYORISTA -46.557882 -107.917462
#
#        num_deliver_per_week  num_visit_per_week
# 10705                     1                   1
# 10706                     1                   1
# 10707                     1                   1
# 10708                     2                   1
# 10709                     3                   1
# ...                     ...                 ...
# 12269                     3                   1
# 12270                     3                   1
# 12271                     3                   1
# 12272                     4                   1
# 12273                     4                   1
#
# [1569 rows x 8 columns]

# %%
data_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1569 entries, 10705 to 12273
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customer_id           1569 non-null   int64
#  1   region_id             1569 non-null   int64
#  2   zone_id               1569 non-null   int64
#  3   customer_type         1569 non-null   object
#  4   Y                     1569 non-null   float64
#  5   X                     1568 non-null   float64
#  6   num_deliver_per_week  1569 non-null   int64
#  7   num_visit_per_week    1569 non-null   int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 110.3+ KB

# %%
data_clientes.nunique()
# Out:
# customer_id             1569
# region_id                  1
# zone_id                    1
# customer_type              7
# Y                       1548
# X                       1552
# num_deliver_per_week       6
# num_visit_per_week         1
# dtype: int64

# %% [markdown]
# * Se quitarán region, zone y num_visit_per_week.

# %% [markdown]
# #### Data productos

# %%
data_productos
# Out:
#      product_id     brand              category sub_category  segment  \
# 0         34092  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM
# 1         57290  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM
# 2         56714  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM
# 3        296616  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM
# 4         60854  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM
# ..          ...       ...                   ...          ...      ...
# 966       33570  Brand 10  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM
# 967      297428   Brand 2  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM
# 968       51974   Brand 2  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM
# 969      297724   Brand 2  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM
# 970       62482   Brand 2  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM
#
#      package  size
# 0    BOTELLA  0.66
# 1    BOTELLA  0.66
# 2    BOTELLA  0.66
# 3    BOTELLA  0.66
# 4    BOTELLA  0.25
# ..       ...   ...
# 966     LATA  0.33
# 967  BOTELLA  0.33
# 968  BOTELLA  0.33
# 969     LATA  0.50
# 970     LATA  0.50
#
# [971 rows x 7 columns]

# %%
data_productos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    971 non-null    int64
#  1   brand         971 non-null    object
#  2   category      971 non-null    object
#  3   sub_category  971 non-null    object
#  4   segment       971 non-null    object
#  5   package       971 non-null    object
#  6   size          971 non-null    float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 53.2+ KB

# %%
data_productos.nunique()
# Out:
# product_id      971
# brand            61
# category          2
# sub_category      3
# segment           4
# package           4
# size             13
# dtype: int64

# %%
data_productos['category'].value_counts()
# Out:
# category
# BEBIDAS CARBONATADAS       743
# BEBIDAS NO CARBONATADAS    228
# Name: count, dtype: int64

# %%
data_productos['sub_category'].value_counts()
# Out:
# sub_category
# GASEOSAS             673
# JUGOS                229
# AGUAS SABORIZADAS     69
# Name: count, dtype: int64

# %%
# Conteo de ocurrencias para cada par distinto (category, sub_category)
category_subcategory_counts = data_productos.groupby(['category', 'sub_category']).size().reset_index(name='counts')
print(category_subcategory_counts)
# Out:
#                   category       sub_category  counts
# 0     BEBIDAS CARBONATADAS  AGUAS SABORIZADAS      69
# 1     BEBIDAS CARBONATADAS           GASEOSAS     673
# 2     BEBIDAS CARBONATADAS              JUGOS       1
# 3  BEBIDAS NO CARBONATADAS              JUGOS     228

# %% [markdown]
# #### Data transacciones

# %%
data_transacciones
# Out:
#          customer_id  product_id  order_id purchase_date     items
# 124            61353       61364    411145    2024-04-27 -0.333333
# 127            61899        1370    411156    2024-04-27  3.666667
# 344           154077       30500    417911    2024-04-29  2.333333
# 349           164337       56714    418100    2024-04-29 -2.333333
# 354           172056       61672    407162    2024-04-26  1.000000
# ...              ...         ...       ...           ...       ...
# 7712445       207330       61364    489755    2024-05-27  1.666667
# 7712469       244971       59396    488047    2024-05-25  3.666667
# 7712538       186657       50716    489529    2024-05-27  3.000000
# 7712547       204243       57414    489725    2024-05-27  1.000000
# 7712548       206748       36720    489748    2024-05-27  3.666667
#
# [254936 rows x 5 columns]

# %%
data_transacciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254936 entries, 124 to 7712548
# Data columns (total 5 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   customer_id    254936 non-null  int64
#  1   product_id     254936 non-null  int64
#  2   order_id       254936 non-null  int64
#  3   purchase_date  254936 non-null  datetime64[ns]
#  4   items          254936 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 11.7 MB

# %%
data_transacciones.nunique()
# Out:
# customer_id       1490
# product_id         114
# order_id         64600
# purchase_date      366
# items              273
# dtype: int64

# %%
data_transacciones['items'].describe()
# Out:
# count    254936.000000
# mean          4.378552
# std          12.098818
# min        -399.666667
# 25%           1.000000
# 50%           2.333333
# 75%           3.666667
# max        1000.333333
# Name: items, dtype: float64

# %%
# Contar cuántas instancias de la columna 'items' son exactamente cero
cantidad_items_cero = (data_transacciones['items'] == 0).sum()
print(f"Cantidad de instancias donde 'items' es cero: {cantidad_items_cero}")
# Out:
# Cantidad de instancias donde 'items' es cero: 1

# %%
# Buscar tuplas duplicadas de (customer_id, product_id, order_id)
duplicados = data_transacciones[data_transacciones.duplicated(subset=['customer_id', 'product_id', 'order_id'], keep=False)]

if not duplicados.empty:
    print("Se encontraron tuplas duplicadas (customer_id, product_id, order_id):")
    display(duplicados)
else:
    print("No se encontraron tuplas duplicadas (customer_id, product_id, order_id) en data_transacciones.")
# Out:
# Se encontraron tuplas duplicadas (customer_id, product_id, order_id):
#          customer_id  product_id  order_id purchase_date     items
# 124            61353       61364    411145    2024-04-27 -0.333333
# 344           154077       30500    417911    2024-04-29  2.333333
# 349           164337       56714    418100    2024-04-29 -2.333333
# 359           176643       56714    418196    2024-04-29 -2.333333
# 362           181593       56714    418241    2024-04-29 -2.333333
# ...              ...         ...       ...           ...       ...
# 7710892       205821       61542    489737    2024-05-27  2.333333
# 7710893       205821       62074    489737    2024-05-27 -0.333333
# 7711475       156489       61364    489422    2024-05-27  1.000000
# 7711488       205821       61364    489737    2024-05-27  2.333333
# 7711885       156489       61364    489422    2024-05-27 -0.333333
#
# [21215 rows x 5 columns]

# %%
duplicados.sort_values(by=['customer_id', 'product_id', 'order_id']).head(20)
# Out:
#          customer_id  product_id  order_id purchase_date      items
# 711515         25734       11262     11063    2024-01-04   4.333333
# 717132         25734       11262     11063    2024-01-04   1.000000
# 5885801        25734       11262    134833    2024-02-07   9.000000
# 5900340        25734       11262    134833    2024-02-07   1.666667
# 4950305        25743        1304    228910    2024-03-05 -23.000000
# 4969453        25743        1304    228910    2024-03-05  23.666667
# 4948166        25743        1370    228910    2024-03-05  -9.666667
# 4978849        25743        1370    228910    2024-03-05  10.333333
# 853098         25743        1370    310477    2024-03-26  13.666667
# 856239         25743        1370    310477    2024-03-26 -13.000000
# 4679548        25743        1370    401402    2024-04-25  10.333333
# 6612132        25743        1370    401402    2024-04-25   7.000000
# 4945197        25743        1372    228910    2024-03-05   2.333333
# 4961094        25743        1372    228910    2024-03-05  -1.666667
# 2729197        25743       11262      7028    2024-01-03  45.666667
# 2746971        25743       11262      7028    2024-01-03   7.000000
# 3457236        25743       11262     31851    2024-01-10   3.000000
# 3459113        25743       11262     31851    2024-01-10  13.666667
# 880648         25743       11262    545785    2024-06-14   1.000000
# 885799         25743       11262    545785    2024-06-14   5.000000

# %% [markdown]
# ### Merge y preprocesamiento

# %%
#PREPROCESAMIENTO DE DATOS

# Se convierten las fechas de compra a tipo datetime
data_transacciones['purchase_date'] = pd.to_datetime(data_transacciones['purchase_date'])

#Se botan duplicados
data_clientes = data_clientes.drop_duplicates()
data_productos = data_productos.drop_duplicates()
data_transacciones = data_transacciones.drop_duplicates()

# Se unen los datasets
df = data_transacciones.merge(data_clientes, on='customer_id', how='left')
df = df.merge(data_productos, on='product_id', how='left')

# Se agrega una columna de semana para agrupar las transacciones por semana
df['week_of_year'] = df['purchase_date'].dt.isocalendar().week
df['year'] = df['purchase_date'].dt.isocalendar().year

# %%
df
# Out:
#         customer_id  product_id  order_id purchase_date     items  region_id  \
# 0             61353       61364    411145    2024-04-27 -0.333333         80
# 1             61899        1370    411156    2024-04-27  3.666667         80
# 2            154077       30500    417911    2024-04-29  2.333333         80
# 3            164337       56714    418100    2024-04-29 -2.333333         80
# 4            172056       61672    407162    2024-04-26  1.000000         80
# ...             ...         ...       ...           ...       ...        ...
# 254046       207330       61364    489755    2024-05-27  1.666667         80
# 254047       244971       59396    488047    2024-05-25  3.666667         80
# 254048       186657       50716    489529    2024-05-27  3.000000         80
# 254049       204243       57414    489725    2024-05-27  1.000000         80
# 254050       206748       36720    489748    2024-05-27  3.666667         80
#
#         zone_id customer_type          Y           X  num_deliver_per_week  \
# 0          5148     ABARROTES -46.558718 -107.860564                     3
# 1          5148     MAYORISTA -46.557632 -107.896470                     3
# 2          5148     ABARROTES -46.543598 -107.874170                     3
# 3          5148     ABARROTES -46.549960 -107.863088                     3
# 4          5148     MAYORISTA -46.564528 -107.927651                     4
# ...         ...           ...        ...         ...                   ...
# 254046     5148     ABARROTES -46.366860 -107.916530                     3
# 254047     5148    CANAL FRIO -46.548378 -107.888458                     3
# 254048     5148     ABARROTES -46.594406 -107.870518                     3
# 254049     5148     ABARROTES -46.587568 -107.911872                     3
# 254050     5148     MAYORISTA -46.438474 -107.477564                     3
#
#         num_visit_per_week     brand              category sub_category  \
# 0                        1  Brand 35  BEBIDAS CARBONATADAS     GASEOSAS
# 1                        1  Brand 34  BEBIDAS CARBONATADAS     GASEOSAS
# 2                        1  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS
# 3                        1  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS
# 4                        1  Brand 34  BEBIDAS CARBONATADAS     GASEOSAS
# ...                    ...       ...                   ...          ...
# 254046                   1  Brand 35  BEBIDAS CARBONATADAS     GASEOSAS
# 254047                   1   Brand 1  BEBIDAS CARBONATADAS     GASEOSAS
# 254048                   1  Brand 44  BEBIDAS CARBONATADAS     GASEOSAS
# 254049                   1  Brand 44  BEBIDAS CARBONATADAS     GASEOSAS
# 254050                   1   Brand 7  BEBIDAS CARBONATADAS     GASEOSAS
#
#         segment  package  size  weef_of_year  year
# 0        MEDIUM  BOTELLA  1.00            17  2024
# 1        MEDIUM  BOTELLA  1.00            17  2024
# 2       PREMIUM     LATA  0.31            18  2024
# 3       PREMIUM  BOTELLA  0.66            18  2024
# 4        MEDIUM     LATA  0.25            17  2024
# ...         ...      ...   ...           ...   ...
# 254046   MEDIUM  BOTELLA  1.00            22  2024
# 254047  PREMIUM  BOTELLA  0.25            21  2024
# 254048     HIGH     LATA  0.25            22  2024
# 254049     HIGH  BOTELLA  1.00            22  2024
# 254050  PREMIUM  BOTELLA  0.66            22  2024
#
# [254051 rows x 20 columns]

# %%
df_sorted = df.sort_values(by=['purchase_date', 'order_id'])
df_sorted
# Out:
#         customer_id  product_id  order_id purchase_date     items  region_id  \
# 108724        61977        1304      2545    2024-01-01  1.666667         80
# 109257        61977       30500      2545    2024-01-01  1.000000         80
# 109908        61977       56714      2545    2024-01-01  3.666667         80
# 111245        66843       30500      2561    2024-01-01  4.333333         80
# 111255        66843       10652      2561    2024-01-01  4.333333         80
# ...             ...         ...       ...           ...       ...        ...
# 128716       251106       56714   1248432    2024-12-31  7.000000         80
# 150373       253557         124   1248450    2024-12-31  3.666667         80
# 150734       253557       63418   1248450    2024-12-31  7.000000         80
# 151086       253557       10652   1248450    2024-12-31  7.000000         80
# 151178       253557       11262   1248450    2024-12-31  7.000000         80
#
#         zone_id customer_type          Y           X  num_deliver_per_week  \
# 108724     5148     ABARROTES -46.435898 -107.454934                     3
# 109257     5148     ABARROTES -46.435898 -107.454934                     3
# 109908     5148     ABARROTES -46.435898 -107.454934                     3
# 111245     5148     MAYORISTA -46.592452 -107.874840                     3
# 111255     5148     MAYORISTA -46.592452 -107.874840                     3
# ...         ...           ...        ...         ...                   ...
# 128716     5148     ABARROTES -46.566578 -107.769280                     2
# 150373     5148     MAYORISTA -46.544154 -107.879978                     3
# 150734     5148     MAYORISTA -46.544154 -107.879978                     3
# 151086     5148     MAYORISTA -46.544154 -107.879978                     3
# 151178     5148     MAYORISTA -46.544154 -107.879978                     3
#
#         num_visit_per_week     brand              category sub_category  \
# 108724                   1   Brand 3  BEBIDAS CARBONATADAS     GASEOSAS
# 109257                   1  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS
# 109908                   1  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS
# 111245                   1  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS
# 111255                   1  Brand 34  BEBIDAS CARBONATADAS     GASEOSAS
# ...                    ...       ...                   ...          ...
# 128716                   1  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS
# 150373                   1  Brand 34  BEBIDAS CARBONATADAS     GASEOSAS
# 150734                   1  Brand 35  BEBIDAS CARBONATADAS     GASEOSAS
# 151086                   1  Brand 34  BEBIDAS CARBONATADAS     GASEOSAS
# 151178                   1  Brand 24  BEBIDAS CARBONATADAS     GASEOSAS
#
#         segment  package  size  week_of_year  year
# 108724   MEDIUM  BOTELLA  1.00             1  2024
# 109257  PREMIUM     LATA  0.31             1  2024
# 109908  PREMIUM  BOTELLA  0.66             1  2024
# 111245  PREMIUM     LATA  0.31             1  2024
# 111255   MEDIUM     LATA  0.25             1  2024
# ...         ...      ...   ...           ...   ...
# 128716  PREMIUM  BOTELLA  0.66             1  2025
# 150373   MEDIUM     LATA  0.33             1  2025
# 150734   MEDIUM     LATA  0.25             1  2025
# 151086   MEDIUM     LATA  0.25             1  2025
# 151178      LOW     LATA  0.25             1  2025
#
# [254051 rows x 20 columns]

# %%
df_sorted.nunique()
# Out:
# customer_id              1490
# product_id                114
# order_id                64600
# purchase_date             366
# items                     273
# region_id                   1
# zone_id                     1
# customer_type               7
# Y                        1472
# X                        1475
# num_deliver_per_week        5
# num_visit_per_week          1
# brand                      21
# category                    1
# sub_category                2
# segment                     4
# package                     3
# size                        7
# week_of_year               52
# year                        2
# dtype: int64

# %%
df_agrupado = df.groupby(['customer_id', 'product_id', 'semana'])['order_id'].count().reset_index()

customer_unicos = df['customer_id'].unique()
productos_unicos = df['product_id'].unique()
semanas_unicas = df['semana'].unique()

customer_unicos_df = pd.DataFrame({'customer_id': customer_unicos})
productos_unicos_df = pd.DataFrame({'product_id': productos_unicos})
semanas_unicas_df = pd.DataFrame({'semana': semanas_unicas})


pares_customer_producto = customer_unicos_df.merge(productos_unicos_df, how='cross')


combinaciones = pares_customer_producto.merge(semanas_unicas_df, how='cross')


data = combinaciones.merge(df_agrupado, on=['customer_id', 'product_id', 'semana'], how='left')


data['order_id'] = data['order_id'].fillna(0)
data['label'] = (data['order_id'] > 0).astype(int)
#del df, customer_unicos_df, productos_unicos_df, semanas_unicas_df, pares_customer_producto, combinaciones, df_agrupado
#gc.collect()

# %%
df_agrupado
# Out:
#         customer_id  product_id                 semana  order_id
# 0             25734         124  2024-01-22/2024-01-28         1
# 1             25734        1304  2024-01-08/2024-01-14         1
# 2             25734        1304  2024-02-05/2024-02-11         1
# 3             25734        1370  2024-01-01/2024-01-07         1
# 4             25734        1370  2024-01-08/2024-01-14         1
# ...             ...         ...                    ...       ...
# 206455      2061063       61542  2024-05-27/2024-06-02         1
# 206456      2061063       62074  2024-05-06/2024-05-12         1
# 206457      2061063       62074  2024-07-15/2024-07-21         1
# 206458      2061063       63510  2024-12-16/2024-12-22         1
# 206459      2061063       63510  2024-12-23/2024-12-29         1
#
# [206460 rows x 4 columns]

# %%
df_agrupado.nunique()
# Out:
# customer_id    1490
# product_id      114
# semana           53
# order_id          9
# dtype: int64

# %%
df_agrupado['order_id'].value_counts()
# Out:
# order_id
# 1    170032
# 2     27725
# 3      6831
# 4      1416
# 5       352
# 6        83
# 7        15
# 8         5
# 9         1
# Name: count, dtype: int64

# %%
data_final = data.merge(data_clientes, on = 'customer_id', how = 'left')
data_final = data_final.merge(data_productos, on = 'product_id', how = 'left')
#del data, data_clientes, data_productos
#gc.collect()
data_final.head()
# Out:
#    customer_id  product_id                 semana  order_id  label  region_id  \
# 0        61353       61364  2024-04-22/2024-04-28       2.0      1         80
# 1        61353       61364  2024-04-29/2024-05-05       1.0      1         80
# 2        61353       61364  2024-01-29/2024-02-04       0.0      0         80
# 3        61353       61364  2024-01-22/2024-01-28       0.0      0         80
# 4        61353       61364  2024-01-08/2024-01-14       0.0      0         80
#
#    zone_id customer_type          Y           X  num_deliver_per_week  \
# 0     5148     ABARROTES -46.558718 -107.860564                     3
# 1     5148     ABARROTES -46.558718 -107.860564                     3
# 2     5148     ABARROTES -46.558718 -107.860564                     3
# 3     5148     ABARROTES -46.558718 -107.860564                     3
# 4     5148     ABARROTES -46.558718 -107.860564                     3
#
#    num_visit_per_week     brand              category sub_category segment  \
# 0                   1  Brand 35  BEBIDAS CARBONATADAS     GASEOSAS  MEDIUM
# 1                   1  Brand 35  BEBIDAS CARBONATADAS     GASEOSAS  MEDIUM
# 2                   1  Brand 35  BEBIDAS CARBONATADAS     GASEOSAS  MEDIUM
# 3                   1  Brand 35  BEBIDAS CARBONATADAS     GASEOSAS  MEDIUM
# 4                   1  Brand 35  BEBIDAS CARBONATADAS     GASEOSAS  MEDIUM
#
#    package  size
# 0  BOTELLA   1.0
# 1  BOTELLA   1.0
# 2  BOTELLA   1.0
# 3  BOTELLA   1.0
# 4  BOTELLA   1.0

# %%
data_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9002580 entries, 0 to 9002579
# Data columns (total 18 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   customer_id           int64
#  1   product_id            int64
#  2   semana                period[W-SUN]
#  3   order_id              float64
#  4   label                 int64
#  5   region_id             int64
#  6   zone_id               int64
#  7   customer_type         object
#  8   Y                     float64
#  9   X                     float64
#  10  num_deliver_per_week  int64
#  11  num_visit_per_week    int64
#  12  brand                 object
#  13  category              object
#  14  sub_category          object
#  15  segment               object
#  16  package               object
#  17  size                  float64
# dtypes: float64(4), int64(7), object(6), period[W-SUN](1)
# memory usage: 1.2+ GB

# %% [markdown]
# **Observación importante:** $1490 \ clientes \cdot 114 \ productos \cdot 53 \ semanas = 9002580$.

# %% [markdown]
# ## 📌 EDA [0.5 puntos]
#
# <center>
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExbHZ6aGdkd21tYTI3cW8zYWhyYW5wdGlyb2s3MmRzeTV0dzQ1NWlueiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/3k1hJubTtOAKPKx4k3/giphy.gif" width="400" height="200">

# %% [markdown]
# En esta sección, se debe realizar un análisis exploratorio de los datos para comprender su estructura, detectar posibles problemas y obtener información relevante para el entrenamiento de los modelos. La idea es que puedan detectar **patrones en los datos** que les permitan resolver el problema con mayor facilidad.
#
# Se deben responder preguntas a partir de lo que puedan visualizar/obtener, por ejemplo:
#
# - Clientes y productos
#
#     - ¿Cuántos clientes únicos hay en el dataset?
#
#     - ¿Cuántos productos únicos se encuentran en los datos?
#
# - Periodo y frecuencia
#
#     - ¿De qué periodo es la información disponible?
#
#     - ¿Cuál es la frecuencia de los registros (diaria, semanal, mensual, etc.)?
#
# - Calidad de los datos
#
#     - ¿Existen valores nulos en el dataset? ¿Cuántos? ¿Cómo se pueden tratar?
#
#     - ¿Hay datos raros, como cantidades negativas o inconsistencias? Genere tests de validación para identificar estos problemas.
#
# - Patrones de compra
#
#     - ¿Cuántos productos compra en promedio cada cliente semana a semana?
#
#     - ¿Cuántas transacciones ha realizado cada cliente?
#
#     - ¿Cuál es el periodo de recompra promedio de cada SKU?

# %%
#data_final.describe()
#estadisticas importantes de data_final

# %%
import matplotlib.pyplot as plt


#Total de clientes únicos
contador_unico_clientes = len(data_transacciones['customer_id'].unique())
print(f"Total de clientes únicos: {contador_unico_clientes}")

#Total de productos únicos
contador_unico_productos = len(data_transacciones['product_id'].unique())
print(f"Total de productos únicos: {contador_unico_productos}")


#¿De qué periodo es la información disponible?
periodo_info = data_final['semana'].min(), data_final['semana'].max()
print(f"Periodo de información: {periodo_info[0]} a {periodo_info[1]}")


#¿Cuál es la frecuencia de los registros (diaria, semanal, mensual, etc.)?
frecuencia_transacciones_diaria  = data_transacciones['purchase_date'].dt.to_period('D').value_counts().sort_index()
frecuencia_transacciones_semanal = data_transacciones['purchase_date'].dt.to_period('W').value_counts().sort_index()
frecuencia_transacciones_mensual = data_transacciones['purchase_date'].dt.to_period('M').value_counts().sort_index()

print(f"Frecuencia media de transacciones por dia: {frecuencia_transacciones_diaria.mean()}")
print(f"Frecuencia media de transacciones por semana: {frecuencia_transacciones_semanal.mean()}")
print(f"Frecuencia media de transacciones por mes: {frecuencia_transacciones_mensual.mean()}")




#frecuencia diaria
plt.figure(figsize=(12, 6))
plt.plot(frecuencia_transacciones_diaria.index.astype(str), frecuencia_transacciones_diaria.values, label='Frecuencia diaria')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
plt.title('Frecuencia diaria de transacciones')
plt.legend()
plt.show()
#frecuencia semanal
plt.figure(figsize=(12, 6))
plt.plot(frecuencia_transacciones_semanal.index.astype(str), frecuencia_transacciones_semanal.values, label='Frecuencia semanal')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
plt.title('Frecuencia semanal de transacciones')
plt.legend()
plt.show()
#frecuencia mensual
plt.figure(figsize=(12, 6))
plt.plot(frecuencia_transacciones_mensual.index.astype(str), frecuencia_transacciones_mensual.values, label='Frecuencia mensual')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
plt.title('Frecuencia mensual de transacciones')
plt.legend()
plt.show()
# Out:
# Total de clientes únicos: 1490
# Total de productos únicos: 114
# Periodo de información: 2024-01-01/2024-01-07 a 2024-12-30/2025-01-05
# Frecuencia media de transacciones por dia: 694.1284153005464
# Frecuencia media de transacciones por semana: 4793.415094339623
# Frecuencia media de transacciones por mes: 21170.916666666668

# %%
#frecuencia diaria maxima y minima
frecuencia_diaria_maxima = frecuencia_transacciones_diaria.max(), frecuencia_transacciones_diaria.idxmax()
frecuencia_diaria_minima = frecuencia_transacciones_diaria.min(), frecuencia_transacciones_diaria.idxmin()
print(f"Frecuencia diaria máxima: {frecuencia_diaria_maxima}")
print(f"Frecuencia diaria mínima: {frecuencia_diaria_minima}")



frecuencia_semanal_maxima = frecuencia_transacciones_semanal.max(), frecuencia_transacciones_semanal.idxmax()
frecuencia_semanal_minima = frecuencia_transacciones_semanal.min(), frecuencia_transacciones_semanal.idxmin()
print(f"Frecuencia diaria máxima: {frecuencia_semanal_maxima}")
print(f"Frecuencia diaria mínima: {frecuencia_semanal_minima}")

frecuencia_mensual_maxima = frecuencia_transacciones_mensual.max(), frecuencia_transacciones_mensual.idxmax()
frecuencia_mensual_minima = frecuencia_transacciones_mensual.min(), frecuencia_transacciones_mensual.idxmin()
print(f"Frecuencia mensual máxima: {frecuencia_mensual_maxima}")
print(f"Frecuencia mensual mínima: {frecuencia_mensual_minima}")
# Out:
# Frecuencia diaria máxima: (2154, Period('2024-04-29', 'D'))
# Frecuencia diaria mínima: (15, Period('2024-05-26', 'D'))
# Frecuencia diaria máxima: (10034, Period('2024-12-16/2024-12-22', 'W-SUN'))
# Frecuencia diaria mínima: (1557, Period('2024-12-30/2025-01-05', 'W-SUN'))
# Frecuencia mensual máxima: (31435, Period('2024-12', 'M'))
# Frecuencia mensual mínima: (13566, Period('2024-05', 'M'))

# %%
#Valores nulos en cada columna de cliente
valores_nulos_clientes = data_clientes.isnull().sum()
print(f"Valores nulos en cada columna:\n{valores_nulos_clientes}")

#Valores nulos en cada columna e producto
valores_nulos_productos = data_productos.isnull().sum()
print(f"Valores nulos en cada columna:\n{valores_nulos_productos}")

#Valores nulos en cada columna de transacciones
valores_nulos_transacciones = data_transacciones.isnull().sum()
print(f"Valores nulos en cada columna:\n{valores_nulos_transacciones}")


#Mencionar como se pueden tratar los valores nulos, eliminando o inputando
# Out:
# Valores nulos en cada columna:
# customer_id             0
# region_id               0
# zone_id                 0
# customer_type           0
# Y                       0
# X                       1
# num_deliver_per_week    0
# num_visit_per_week      0
# dtype: int64
# Valores nulos en cada columna:
# product_id      0
# brand           0
# category        0
# sub_category    0
# segment         0
# package         0
# size            0
# dtype: int64
# Valores nulos en cada columna:
# customer_id      0
# product_id       0
# order_id         0
# purchase_date    0
# items            0
# dtype: int64

# %%
#Test de validacion
valores_negativos_items = data_transacciones[data_transacciones['items'] < 0]
print(f"Valores negativos en la columna items: {len(valores_negativos_items)}")

valores_duplicados = data_final.duplicated().sum()
print(f"Valores duplicados: {valores_duplicados}")

valores_malos_fechas = data_transacciones[data_transacciones['purchase_date'] > pd.Timestamp.now()]
print(f"Valores con fechas futuras: {len(valores_malos_fechas)}")


#Elaborar el resultado mencionando lo que se encontró
# Out:
# Valores negativos en la columna items: 8346
# Valores duplicados: 0
# Valores con fechas futuras: 0

# %%
#Patrones de compra

#Promedio de compra por cliente semana a semana
compras_semanales = data_transacciones.groupby(['customer_id',data_transacciones['purchase_date'].dt.to_period('W')])['items'].sum().reset_index()
promedio_compras_semanales = compras_semanales.groupby('customer_id')['items'].mean()
promedio_compras_semanales_max = promedio_compras_semanales.max(), promedio_compras_semanales.idxmax()
promedio_compras_semanales_min = promedio_compras_semanales.min(), promedio_compras_semanales.idxmin()
print(f"Promedio de compras semanales máximo: {promedio_compras_semanales_max}")
print(f"Promedio de compras semanales mínimo: {promedio_compras_semanales_min}")
print(f"Promedio de compras semnales media: {promedio_compras_semanales.mean()}")

plt.figure(figsize=(12, 6))
plt.plot(promedio_compras_semanales.index.astype(str), promedio_compras_semanales.values, label='Promedio de compras semanales')
plt.xlabel('Cliente')
plt.ylabel('Promedio de compras semanales')
plt.title('Promedio de compras semanales por cliente')
plt.legend()
plt.show()
# Out:
# Promedio de compras semanales máximo: (771.2517006802722, np.int64(181101))
# Promedio de compras semanales mínimo: (1.0, np.int64(203466))
# Promedio de compras semnales media: 18.79800424279703

# %%
#Cantidad de transacciones por cliente
cantidad_transacciones_por_clientes = data_transacciones.groupby('customer_id').size().reset_index()
cantidad_transacciones_por_clientes.columns = ['customer_id', 'cantidad_transacciones']
plt.figure(figsize=(12, 6))
plt.plot(cantidad_transacciones_por_clientes['customer_id'].astype(str), cantidad_transacciones_por_clientes['cantidad_transacciones'], label='Cantidad de transacciones')
plt.xlabel('Cliente')
plt.ylabel('Cantidad de transacciones')
plt.title('Cantidad de transacciones por cliente')
plt.legend()
plt.show()


#Cantidad máxima y minima de transacciones

cantidad_maxima_transaccionadas = (cantidad_transacciones_por_clientes['cantidad_transacciones'].max(),cantidad_transacciones_por_clientes.loc[cantidad_transacciones_por_clientes['cantidad_transacciones'].idxmax(), 'customer_id'])

cantidad_minima_transaccionadas = (cantidad_transacciones_por_clientes['cantidad_transacciones'].min(),cantidad_transacciones_por_clientes.loc[cantidad_transacciones_por_clientes['cantidad_transacciones'].idxmin(), 'customer_id']
)
print(f"Cantidad máxima de transacciones: {cantidad_maxima_transaccionadas}")
print(f"Cantidad mínima de transacciones: {cantidad_minima_transaccionadas}")
# Out:
# Cantidad máxima de transacciones: (1600, np.int64(183105))
# Cantidad mínima de transacciones: (1, np.int64(203466))

# %%
#promedio periodo recompra para cada SKU.

data_transacciones = data_transacciones.sort_values(by=['product_id', 'purchase_date'])
data_transacciones['diff_dias'] = data_transacciones.groupby('product_id')['purchase_date'].diff().dt.days


periodo_recompra_promedio = data_transacciones.groupby('product_id')['diff_dias'].mean().reset_index()
periodo_recompra_promedio.columns = ['product_id', 'periodo_recompra_promedio']

plt.figure(figsize=(12, 6))
plt.plot(periodo_recompra_promedio['product_id'].astype(str), periodo_recompra_promedio['periodo_recompra_promedio'], label='Periodo de recompra promedio')
plt.xlabel('SKU')
plt.ylabel('Periodo de recompra promedio')
plt.title('Periodo de recompra promedio por SKU')
plt.legend()
plt.show()


#promedio maximo y minimo periodo recompra para cada SKU.



periodo_recompra_maximo = periodo_recompra_promedio['periodo_recompra_promedio'].max(), periodo_recompra_promedio.loc[periodo_recompra_promedio['periodo_recompra_promedio'].idxmax(), 'product_id']
periodo_recompra_minimo = periodo_recompra_promedio['periodo_recompra_promedio'].min(), periodo_recompra_promedio.loc[periodo_recompra_promedio['periodo_recompra_promedio'].idxmin(), 'product_id']

print(f"Periodo de recompra máximo: {periodo_recompra_maximo}")
print(f"Periodo de recompra mínimo: {periodo_recompra_minimo}")
print(f"Periodo de recompra promedio: {periodo_recompra_promedio['periodo_recompra_promedio'].mean()}")
# Out:
# Periodo de recompra máximo: (343.0, np.int64(52620))
# Periodo de recompra mínimo: (0.009701512372750711, np.int64(1370))
# Periodo de recompra promedio: 9.2969876857259

# %%
del frecuencia_transacciones_diaria, frecuencia_transacciones_semanal, frecuencia_transacciones_mensual, contador_unico_clientes, contador_unico_productos
gc.collect

del frecuencia_diaria_maxima, frecuencia_diaria_minima, frecuencia_semanal_maxima, frecuencia_semanal_minima, frecuencia_mensual_maxima, frecuencia_mensual_minima
gc.collect

del periodo_info, promedio_compras_semanales_max, promedio_compras_semanales_min, cantidad_maxima_transaccionadas, cantidad_minima_transaccionadas
gc.collect

del periodo_recompra_maximo, periodo_recompra_minimo

# %%
del df, customer_unicos_df, productos_unicos_df, semanas_unicas_df, pares_customer_producto, combinaciones, df_agrupado, data
#gc.collect()

# %% [markdown]
# ## 📌 Holdout [0.25 puntos]
#
# Para evaluar correctamente el modelo y garantizar su capacidad de generalización, se deben dividir los datos en tres conjuntos:
# - `Entrenamiento` : Para ajustar los parámetros.
# - `Validación`: Para optimizar hiperparámetros y seleccionar el mejor modelo.
# - `Prueba` : Para evaluar el rendimiento final en datos no vistos.
#
# 👀 **Hint**: *Recuerde que los datos tienen una temporalidad que debe considerarse al momento de separarlos, para evitar fugas de información. Es importante justificar la estrategia de partición elegida y visualizar la distribución temporal de los conjuntos generados*

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

#mencionar que es necesario respetar la secuencia temporal, por eso se usa shuffle = False, para que no mezcle datos
data_final = data_final.sort_values(by='semana')



#separacion datset de entreamiento, valiacion y testeo
train_data, val_test_data = train_test_split(data_final, test_size=0.3, random_state=42, shuffle=False)
val_data, test_data = train_test_split(val_test_data, test_size=0.5, random_state=42, shuffle=False)



#train_data1 = train_data.copy()
#val_data1 = val_data.copy()
#test_data1 = test_data.copy()

X_train = train_data.drop(columns=['label', 'product_id', 'customer_id'])
y_train = train_data['label']
X_val = val_data.drop(columns=['label', 'product_id', 'customer_id'])
y_val = val_data['label']
X_test = test_data.drop(columns=['label', 'product_id', 'customer_id'])
y_test = test_data['label']


conteo_semana_train = train_data['semana'].value_counts().sort_index()
conteo_semana_val = val_data['semana'].value_counts().sort_index()
conteo_semana_test = test_data['semana'].value_counts().sort_index()

conteo_semana_train.idx = conteo_semana_train.index.astype(str)
conteo_semana_val.idx = conteo_semana_val.index.astype(str)
conteo_semana_test.idx = conteo_semana_test.index.astype(str)



print(f"Datos de entrenamiento: {train_data.shape[0]} filas")
print(f"Datos de validación: {val_data.shape[0]} filas")
print(f"Datos de prueba: {test_data.shape[0]} filas")



#se plotea los datasets para mostrar que se mantiene temporalidad
plt.figure(figsize=(12, 6))
plt.bar(conteo_semana_train.idx,conteo_semana_train.values , alpha = 0.5, label='Entrenamiento')
plt.bar(conteo_semana_val.idx, conteo_semana_val.values, alpha = 0.5, label='Validación')
plt.bar(conteo_semana_test.idx, conteo_semana_test.values, alpha = 0.5, label='Prueba')
plt.xlabel('Semana')
plt.ylabel('Frecuencia')
plt.title('Distribución de semanas en los conjuntos de datos')
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend()
plt.show()

del conteo_semana_train, conteo_semana_val, conteo_semana_test
gc.collect()
# Out:
# Datos de entrenamiento: 6301806 filas
# Datos de validación: 1350387 filas
# Datos de prueba: 1350387 filas
# 11117

# %% [markdown]
# ## 📌 Feature Engineering [0.5 puntos]
#
# <center>
# <img src="https://i.imgur.com/CmXZSSC.gif" width="300" height="200">

# %% [markdown]
# En esta sección, se deben construir pipelines para automatizar el preprocesamiento de los datos, lo cual garantizará que el flujo de trabajo sea reproducible y eficiente para esta entrega y las futuras. El objetivo es aplicar una serie de transformaciones en un orden definido para asegurar que los datos estén listos para los modelos a entrenar. El pipeline final debe incluir las técnicas de pre-procesamiento que se deben aplicar a los distintos datos (según lo que consideren necesario para el problema). Por ejemplo:
#
# - **Imputación de valores nulos**: Manejo de datos faltantes mediante estrategias adecuadas (media, mediana, moda, interpolación, etc.).
#
# - **Transformaciones personalizadas**: Uso de ColumnTransformer para aplicar diferentes transformaciones a columnas específicas.
#
# - **Codificación de variables categóricas**: Convertir datos categóricos a un formato numérico adecuado (One-Hot Encoding, Label Encoding, etc.).
#
# - **Discretización de variables**: Conversión de variables numéricas continuas en categorías si son relevantes para el desempeño del modelo a entrenar.
#
# - **Estandarización o normalización** : Ajustar la escala de los datos para mejorar el rendimiento de los algoritmos sensibles a la magnitud de las variables.
#
# - **Eliminación o transformación de valores atípicos**: Identificar y tratar con datos outliers para mejorar la robustez del modelo.
#
# - **Nuevas características** : Creación de variables adicionales que puedan aportar información relevante al modelo.
#
# Cada una de estas transformaciones debe ser justificada en función de su relevancia para el problema y los datos, y es importante evaluar su impacto en el rendimiento del modelo. Además, el pipeline debe ser flexible y modular para poder probar diferentes configuraciones de preprocesamiento.

# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,OneHotEncoder,KBinsDiscretizer
from sklearn.preprocessing import FunctionTransformer


#variables categroicas,numericas y continuas
cat = data_final.select_dtypes(include=['object']).columns.tolist()
num = data_final.select_dtypes(include=['int64']).columns.tolist()
cont = data_final.select_dtypes(include=['float64']).columns.tolist()
num.remove('label')
num.remove('customer_id')
num.remove('product_id')



#funcion paa extraer fecha en formato año, mes y dia
def extraer_semana(X):
    if isinstance(X, pd.DataFrame):
        semana_series = X['semana']
    elif isinstance(X, pd.Series):
        semana_series = X['semana']

    semana_ints = semana_series.astype(int)
    semana_procesada = semana_ints.to_numpy().reshape(-1, 1).astype(float)
    return semana_procesada

#preprocesor para inputar valores nulos y escalar los datos tanto numericos y categoricos, ademas de discretizar valores continuos

# Pipeline Numerica
num_pipeline = Pipeline([
    ('impute', SimpleImputer(strategy='median')),
    ('scale', StandardScaler())
])

# Discretización con KBins
kbins_pipeline = Pipeline([
    ('impute', SimpleImputer(strategy='median')),
    ('kbins', KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='quantile'))
])

# Pipeline Categórica
cat_pipeline = Pipeline([
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# Semana transformada
semana_pipeline = Pipeline([
    ('extract', FunctionTransformer(extraer_semana, validate=False)),
    ('impute', SimpleImputer(strategy='constant', fill_value=0.0)),
    ('scale', StandardScaler())
])

# ColumnTransformer general
preprocessor = ColumnTransformer(transformers=[
    ('num', num_pipeline, num),
    ('cont', kbins_pipeline, cont),
    ('cat', cat_pipeline, cat),
    ('semana', semana_pipeline, ['semana'])
], remainder='drop')

# %% [markdown]
# ## 📌 Baseline [0.25 puntos]
#
# <center>
# <img src="https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExN3lzeGFqZmU3NzJrZHllNjRmaHVzczJpZ29rdHdlMzVpZnQwNXo1diZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/qAtZM2gvjWhPjmclZE/giphy.gif" width="300" height="200">

# %% [markdown]
# En esta sección se debe construir el modelo más sencillo posible que pueda resolver el problema planteado, conocido como **Modelo baseline**. Su propósito es servir como referencia para comparar el rendimiento de los modelos más avanzados desarrollados en etapas posteriores.
#
# Pasos requeridos:
# - Implemente, entrene y evalúe un modelo básico utilizando un pipeline.
# - Asegúrese de incluir en el pipeline las transformaciones del preprocesamiento realizadas previamente junto con un clasificador básico.
# - Evalúe el modelo y presente el informe de métricas utilizando **`classification_report`**.
#
# Documente claramente cómo se creó el modelo, las decisiones tomadas y los resultados obtenidos. Este modelo será la base comparativa en las secciones posteriores.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

#pipeline para preprocesar y aplicar modelo baseline
pipeline_baseline = Pipeline([
    ('preprocessor', preprocessor),
    ('modelo', LogisticRegression(max_iter=1000, solver='liblinear', random_state=42, class_weight= 'balanced'))
])
#preparar el pipleine con datos de entrenamiento
pipeline_baseline.fit(X_train,y_train)
y_val_pred = pipeline_baseline.predict(X_val)

print("Reporte de clasificación para el modelo base:")
print(classification_report(y_val, y_val_pred))

# esto esta muy raro, con un dummyclasifier se obtiene 97% de precision en la label no compro, luego en la de si compro obtiene 0
# estos si o si viene del desbalance de las clases
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-10-2155231698.py in <cell line: 0>()
#      10 ])
#      11 #preparar el pipleine con datos de entrenamiento
# ---> 12 pipeline_baseline.fit(X_train,y_train)
#      13 y_val_pred = pipeline_baseline.predict(X_val)
#      14
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py in fit(self, X, y, **params)
#     652
#     653         routed_params = self._check_method_params(method="fit", props=params)
# --> 654         Xt = self._fit(X, y, routed_params, raw_params=params)
#     655         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     656             if self._final_estimator != "passthrough":
#
# /usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py in _fit(self, X, y, routed_params, raw_params)
#     586             )
#     587
# --> 588             X, fitted_transformer = fit_transform_one_cached(
#     589                 cloned_transformer,
#     590                 X,
#
# /usr/local/lib/python3.11/dist-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     324
#     325     def __call__(self, *args, **kwargs):
# --> 326         return self.func(*args, **kwargs)
#     327
#     328     def call_and_shelve(self, *args, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1549     with _print_elapsed_time(message_clsname, message):
#    1550         if hasattr(transformer, "fit_transform"):
# -> 1551             res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1552         else:
#    1553             res = transformer.fit(X, y, **params.get("fit", {})).transform(
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py in fit_transform(self, X, y, **params)
#     999             routed_params = self._get_empty_routing()
#    1000
# -> 1001         result = self._call_func_on_transformers(
#    1002             X,
#    1003             y,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py in _call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     908                 )
#     909
# --> 910             return Parallel(n_jobs=self.n_jobs)(jobs)
#     911
#     912         except ValueError as e:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#      78
#      79
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1984             output = self._get_sequential_output(iterable)
#    1985             next(output)
# -> 1986             return output if self.return_generator else list(output)
#    1987
#    1988         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1912                 self.n_dispatched_batches += 1
#    1913                 self.n_dispatched_tasks += 1
# -> 1914                 res = func(*args, **kwargs)
#    1915                 self.n_completed_tasks += 1
#    1916                 self.print_progress()
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     137             config = {}
#     138         with config_context(**config):
# --> 139             return self.function(*args, **kwargs)
#     140
#     141
#
# /usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1549     with _print_elapsed_time(message_clsname, message):
#    1550         if hasattr(transformer, "fit_transform"):
# -> 1551             res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1552         else:
#    1553             res = transformer.fit(X, y, **params.get("fit", {})).transform(
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py in fit_transform(self, X, y, **params)
#     716         """
#     717         routed_params = self._check_method_params(method="fit_transform", props=params)
# --> 718         Xt = self._fit(X, y, routed_params)
#     719
#     720         last_step = self._final_estimator
#
# /usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py in _fit(self, X, y, routed_params, raw_params)
#     586             )
#     587
# --> 588             X, fitted_transformer = fit_transform_one_cached(
#     589                 cloned_transformer,
#     590                 X,
#
# /usr/local/lib/python3.11/dist-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     324
#     325     def __call__(self, *args, **kwargs):
# --> 326         return self.func(*args, **kwargs)
#     327
#     328     def call_and_shelve(self, *args, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1549     with _print_elapsed_time(message_clsname, message):
#    1550         if hasattr(transformer, "fit_transform"):
# -> 1551             res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1552         else:
#    1553             res = transformer.fit(X, y, **params.get("fit", {})).transform(
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     919         else:
#     920             # fit method of arity 2 (supervised transformation)
# --> 921             return self.fit(X, y, **fit_params).transform(X)
#     922
#     923
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/impute/_base.py in fit(self, X, y)
#     449             )
#     450         else:
# --> 451             self.statistics_ = self._dense_fit(
#     452                 X, self.strategy, self.missing_values, fill_value
#     453             )
#
# /usr/local/lib/python3.11/dist-packages/sklearn/impute/_base.py in _dense_fit(self, X, strategy, missing_values, fill_value)
#     531         # Median
#     532         elif strategy == "median":
# --> 533             median_masked = np.ma.median(masked_X, axis=0)
#     534             # Avoid the warning "Warning: converting a masked element to nan."
#     535             median = np.ma.getdata(median_masked)
#
# /usr/local/lib/python3.11/dist-packages/numpy/ma/extras.py in median(a, axis, out, overwrite_input, keepdims)
#     784             return m
#     785
# --> 786     return _ureduce(a, func=_median, keepdims=keepdims, axis=axis, out=out,
#     787                     overwrite_input=overwrite_input)
#     788
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py in _ureduce(a, func, keepdims, **kwargs)
#    3762                 kwargs['out'] = out[(Ellipsis, ) + index_out]
#    3763
# -> 3764     r = func(a, **kwargs)
#    3765
#    3766     if out is not None:
#
# /usr/local/lib/python3.11/dist-packages/numpy/ma/extras.py in _median(a, axis, out, overwrite_input)
#     803             asorted = a
#     804     else:
# --> 805         asorted = sort(a, axis=axis, fill_value=fill_value)
#     806
#     807     if axis is None:
#
# /usr/local/lib/python3.11/dist-packages/numpy/ma/core.py in sort(a, axis, kind, order, endwith, fill_value, stable)
#    7169
#    7170     if isinstance(a, MaskedArray):
# -> 7171         a.sort(axis=axis, kind=kind, order=order, endwith=endwith,
#    7172                fill_value=fill_value, stable=stable)
#    7173     else:
#
# /usr/local/lib/python3.11/dist-packages/numpy/ma/core.py in sort(self, axis, kind, order, endwith, fill_value, stable)
#    5839             return
#    5840
# -> 5841         sidx = self.argsort(axis=axis, kind=kind, order=order,
#    5842                             fill_value=fill_value, endwith=endwith)
#    5843
#
# /usr/local/lib/python3.11/dist-packages/numpy/ma/core.py in argsort(self, axis, kind, order, endwith, fill_value, stable)
#    5666
#    5667         filled = self.filled(fill_value)
# -> 5668         return filled.argsort(axis=axis, kind=kind, order=order)
#    5669
#    5670     def argmin(self, axis=None, fill_value=None, out=None, *,
#
# KeyboardInterrupt:

# %%
del pipeline_baseline
import gc
gc.collect()

# %% [markdown]
# ## 📌 Elección de modelo [0.75 puntos]
#
# En esta sección deben escoger un modelo que se adapte a las necesidades del negocio. Para esto, pruebe al menos 3 modelos y desarrolle los siguientes aspectos para cada uno:
#
# - **Estructura y diferencias entre los modelos**: Explicar brevemente cada uno y sus hipérparámetros de mayor importancia.
# - **Clasificadores recomendados**:
#   - `LogisticRegression`
#   - `KNeighborsClassifier`
#   - `DecisionTreeClassifier`
#   - `SVC`
#   - `RandomForestClassifier`
#   - `LightGBMClassifier` (del paquete `lightgbm`)
#   - `XGBClassifier` (del paquete `xgboost`)
#   - Otro (según lo que se estime adecuado)
#
# - **Evaluación de resultados**: Se utilizará el **`classification_report`** para evaluar el rendimiento de cada modelo, destacando métricas clave como precisión, recall y F1-score. **Importante: No optimicen hiperparámetros, la idea es hacer una selección rápida del modelo.**
#
# **Nota:** Pueden ocupar mas de 1 **instancia** de modelo para resolver el problema (e.g: (modelo_1, grupo_1), (modelo_2, grupo_2), ...).
#
# A continuación, se deben responder las siguientes preguntas para evaluar el rendimiento de los modelos entrenados:
#
# 1. ¿Hay algún clasificador que supere al modelo baseline?
# 2. ¿Cuál es el mejor clasificador entrenado y por qué?
# 3. ¿Qué factores hacen que el mejor clasificador sea superior a los otros?
# 4. En términos de `tiempo de entrenamiento`, ¿Qué modelo considera más adecuado para experimentar con grillas de optimización?

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
import gc


# modelos mencionados
modelos = {
    'Logistic Regression': LogisticRegression(
        class_weight='balanced',
        max_iter=1000,
        solver='liblinear',
        random_state=42),

    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(n_estimators = 100, random_state=42, max_depth = 8, n_jobs=-1, class_weight='balanced'),

    'XGBoost': XGBClassifier(objective='binary:logistic', n_estimators = 100, learning_rate = 0.1, max_depth = 6, eval_metric='logloss', use_label_encoder=False, random_state=42),
    #'SVM': SVC(random_state=42),
    'LightGBM': LGBMClassifier(objective='binary', random_state=42)
}
#iteracion para modelos y preprocesamiento en cada pipeline
for nombre, modelo in modelos.items():
    pipeline_name = f'pipeline_{nombre.replace(" ", "_").lower()}'
    pipeline_modelo = Pipeline([
        ('preprocessor', preprocessor),
        ('modelo', modelo)
    ])
    globals()[pipeline_name] = pipeline_modelo


    pipeline_modelo.fit(X_train, y_train)
    y_val_pred = pipeline_modelo.predict(X_val)
    #y_test_pred = pipeline.predict(X_test)
    print(f"Reporte de clasificación para el modelo {nombre} en el conjunto de validacion:")
    print(classification_report(y_val, y_val_pred))
    #print(f"Reporte de clasificación para el modelo {nombre} en el conjunto de prueba:")
    #print(classification_report(y_test, y_test_pred))
    del pipeline_modelo
    gc.collect()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 3 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# Reporte de clasificación para el modelo Logistic Regression en el conjunto de validacion:
#               precision    recall  f1-score   support
#
#            0       0.99      0.74      0.84   1315393
#            1       0.07      0.77      0.13     34994
#
#     accuracy                           0.74   1350387
#    macro avg       0.53      0.75      0.49   1350387
# weighted avg       0.97      0.74      0.83   1350387
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 3 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# Reporte de clasificación para el modelo Decision Tree en el conjunto de validacion:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98   1315393
#            1       0.13      0.04      0.06     34994
#
#     accuracy                           0.97   1350387
#    macro avg       0.55      0.52      0.52   1350387
# weighted avg       0.95      0.97      0.96   1350387
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 3 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# Reporte de clasificación para el modelo Random Forest en el conjunto de validacion:
#               precision    recall  f1-score   support
#
#            0       0.99      0.77      0.86   1315393
#            1       0.08      0.77      0.15     34994
#
#     accuracy                           0.77   1350387
#    macro avg       0.54      0.77      0.50   1350387
# weighted avg       0.97      0.77      0.85   1350387
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 3 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [21:27:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Reporte de clasificación para el modelo XGBoost en el conjunto de validacion:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99   1315393
#            1       0.49      0.00      0.00     34994
#
#     accuracy                           0.97   1350387
#    macro avg       0.73      0.50      0.50   1350387
# weighted avg       0.96      0.97      0.96   1350387
#
# [LightGBM] [Info] Number of positive: 133069, number of negative: 6168737
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.843955 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 134
# [LightGBM] [Info] Number of data points in the train set: 6301806, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.021116 -> initscore=-3.836382
# [LightGBM] [Info] Start training from score -3.836382
# Reporte de clasificación para el modelo LightGBM en el conjunto de validacion:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99   1315393
#            1       0.53      0.00      0.01     34994
#
#     accuracy                           0.97   1350387
#    macro avg       0.75      0.50      0.50   1350387
# weighted avg       0.96      0.97      0.96   1350387

# %% [markdown]
# ## 📌 Optimización de Hiperparámetros [1.0 puntos]
#
# <center>
# <img src="https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExcXJkNzdhYjlneHplaGpsbnVkdzh5dnY3Y2VyaTIzamszdGR1czJ2diZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/2rqEdFfkMzXmo/giphy.gif" width="300" height="200">

# %% [markdown]
# A partir de su análisis anterior, se debe proceder a optimizar el rendimiento del modelo seleccionado mediante la optimización de sus hiperparámetros. Para ello, se espera que implementen `Optuna` para optimizar no solo los hiperparámetros del modelo, sino también los de los preprocesadores utilizados (por ejemplo, OneHot Encoding, Scalers, etc.).
#
# Al desarrollar este proceso, deberán responder las siguientes preguntas clave como mínimo:
#
# - ¿Qué métrica decidieron optimizar y por qué?
#
# - ¿Qué hiperparámetro tuvo un mayor impacto en el rendimiento de su modelo?
#
# - ¿Cuánto mejoró el rendimiento del modelo después de la optimización de hiperparámetros?

# %%
#!pip install optuna

# %%
import optuna
from optuna.visualization import plot_optimization_history
from optuna.visualization import plot_parallel_coordinate
from optuna.visualization import plot_param_importances
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.preprocessing import LabelEncoder

# %%
def objective(trial):
  le = LabelEncoder()
  y_train_encoded = le.fit_transform(y_train)
  y_val_encoded = le.transform(y_val)

  bins       = trial.suggest_int("n_bins", 3, 10)
  n_estimators = trial.suggest_int("n_estimators", 50, 300)
  max_depth    = trial.suggest_int("max_depth", 5, 30)
  max_features = trial.suggest_categorical("max_features", ["sqrt","log2",None])

  num_pipeline1 = Pipeline([
    ('impute', SimpleImputer(strategy='median')),
    ('scale', StandardScaler())
    ])

# Discretización con KBins
  kbins_pipeline1 = Pipeline([
    ('impute', SimpleImputer(strategy='median')),
    ('kbins', KBinsDiscretizer(n_bins=bins, encode='ordinal', strategy='quantile'))
  ])

# Pipeline Categórica
  cat_pipeline1 = Pipeline([
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
  ])

# Semana transformada
  semana_pipeline1 = Pipeline([
    ('extract', FunctionTransformer(extraer_semana, validate=False)),
    ('impute', SimpleImputer(strategy='constant', fill_value=0.0)),
    ('scale', StandardScaler())
  ])

# ColumnTransformer general
  preprocessor1 = ColumnTransformer(transformers=[
    ('num', num_pipeline1, num),
    ('cont', kbins_pipeline1, cont),
    ('cat', cat_pipeline1, cat),
    ('semana', semana_pipeline1, ['semana'])
    ], remainder='drop')




  modelo = RandomForestClassifier(n_estimators = n_estimators, max_depth=max_depth, max_features = max_features, n_jobs = -1, random_state=42, class_weight = "balanced")

  pipeline1 = Pipeline([
    ('preprocessor', preprocessor1),
    ('modelo', modelo)
    ])

  pipeline1.fit(X_train,y_train)

  y_val_pred = pipeline1.predict(X_val)
  f1 = f1_score(y_val_encoded, y_val_pred, average = 'macro')

  trial.report(f1, step=0)
  if trial.should_prune():
      raise optuna.exceptions.TrialPruned()
  return f1

# %%
def objective(trial):
  le = LabelEncoder()
  y_train_encoded = le.fit_transform(y_train)
  y_val_encoded = le.transform(y_val)


  n_estimators = trial.suggest_int("n_estimators", 50, 250)
  max_depth    = trial.suggest_int("max_depth", 5, 25)
  max_features = trial.suggest_categorical("max_features", ["sqrt","log2",None])



  modelo = RandomForestClassifier(n_estimators = n_estimators, max_depth=max_depth, max_features = max_features, n_jobs = -1, random_state=42, class_weight = "balanced")

  pipeline1 = Pipeline([
    ('preprocessor', preprocessor),
    ('modelo', modelo)
    ])

  pipeline1.fit(X_train,y_train)

  y_val_pred = pipeline1.predict(X_val)
  f1 = f1_score(y_val_encoded, y_val_pred, average = 'macro')

  trial.report(f1, step=0)
  if trial.should_prune():
      raise optuna.exceptions.TrialPruned()
  return f1

# %%
from optuna.pruners import MedianPruner
import time
start_time = time.time()
N_TRIALS = 30
def progress_callback(study, trial):
    elapsed   = time.time() - start_time
    done      = trial.number + 1
    avg_time  = elapsed / done
    remaining = avg_time * (N_TRIALS - done)
    print(f"✔️ Trial {done}/{N_TRIALS} | "
          f"Best AP: {study.best_value:.4f} | "
          f"Elapsed: {elapsed:.0f}s | ETA: {remaining:.0f}s")

study = optuna.create_study(direction="maximize", pruner=MedianPruner(n_startup_trials=5, n_warmup_steps=0), sampler=optuna.samplers.TPESampler(n_startup_trials=5))
study.optimize(objective, n_trials=N_TRIALS, callbacks=[progress_callback])

# 9) Resultados finales
print("\n🎯 Mejor Average Precision:", study.best_value)
print("🔧 Mejores parámetros:")
for param, val in study.best_params.items():
    print(f"  • {param}: {val}")
# Out:
# [I 2025-06-26 01:48:22,346] A new study created in memory with name: no-name-a1af23f6-1a93-4561-bbf8-879afe2ba040
# [I 2025-06-26 01:59:39,487] Trial 0 finished with value: 0.5003090501469432 and parameters: {'n_estimators': 55, 'max_depth': 15, 'max_features': 'log2'}. Best is trial 0 with value: 0.5003090501469432.
# ✔️ Trial 1/30 | Best AP: 0.5003 | Elapsed: 677s | ETA: 19637s

# %%
plot_optimization_history(study)
plot_parallel_coordinate(study)
plot_param_importances(study)
print("Mejor conjunto de hiperparámetros:")
print(study.best_params)
print("Mejor valor de la métrica f1:")
print(study.best_value)

# %% [markdown]
# ## 📌 Interpretabilidad [1.0 puntos]
#
# En esta sección, deben explicar el funcionamiento de su modelo utilizando las técnicas de interpretabilidad vistas en clase, como `SHAP`. Se espera que sean capaces de descomponer las predicciones y evaluar la importancia de los atributos y las interacciones entre ellos, con el fin de obtener una comprensión más profunda de cómo el modelo toma decisiones.
#
# Al desarrollar esta parte, deberán responder las siguientes preguntas clave como mínimo:
#
# - ¿Podría explicar el funcionamiento de su modelo para una predicción en particular? Si es así, proporcione al menos tres ejemplos específicos, describiendo cómo el modelo llegó a sus decisiones y qué factores fueron más relevantes en cada caso.
#
# - ¿Qué atributo tiene una mayor importancia en la salida de su modelo? Analice si esto tiene sentido con el problema planteado y justifique la relevancia de dicho atributo en el contexto de las predicciones que se realizan.
#
# - ¿Existe alguna interacción entre atributos que sea relevante para el modelo? Investigue si la combinación de ciertos atributos tiene un impacto significativo en las predicciones y explíquela en **detalle**.
#
# - ¿Podría existir sesgo hacia algún atributo en particular? Reflexione sobre la posibilidad de que el modelo esté favoreciendo ciertos atributos. Si es así, ¿cuál podría ser la causa y qué impacto podría tener esto en la predicción?

# %%
# Desarrolle aquí su código

# %% [markdown]
# ## 📌 Resultados y Conclusiones [1.0 puntos]
#
# Para finalizar, se deben explicar los desarrollos y resultados obtenidos a lo largo de todo el proceso, desde la selección de las variables hasta la optimización de hiperparámetros e interpretación. Se espera una reflexión crítica sobre el desempeño de los modelos entrenados y una comparación entre los diferentes enfoques. Además, deberán abordar los siguientes puntos clave:
#
# - **Análisis de métricas**: Comenten sobre las métricas obtenidas en cada etapa del modelo, destacando las más relevantes como precisión, recall, F1-score, etc. ¿Cuáles fueron los modelos más efectivos? ¿Qué diferencias notables encontró entre ellos?
#
# - **Impacto de las decisiones tomadas**: Reflexionen sobre cómo las decisiones relacionadas con el preprocesamiento, selección de atributos y optimización de hiperparámetros influyeron en los resultados finales. ¿Hubo alguna decisión que haya tenido un impacto notable en el rendimiento?
#
# - **Lecciones aprendidas**: Concluyan sobre las lecciones más importantes que aprendieron durante el proceso y cómo estas pueden influir en futuras iteraciones del modelo. ¿Qué se podría mejorar si se repitiera el proceso? Si tuvieran más recursos y tiempo, ¿qué otras técnicas/herramientas habrían utilizado?

# %% [markdown]
# > [Escriba aquí sus resultados]

# %% [markdown]
# Mucho éxito!
#
# <center>
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExaHpvOTY5Z3hpdHI3aDBpdGRueXRqamZncXp2emFrbjJ5M2s5eTR1dSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/1PMVNNKVIL8Ig/giphy.gif" width="300" height="200">
